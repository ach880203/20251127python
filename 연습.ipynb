# %%
divmod(10, 3)
# Out:
# (3, 1)

# %%
a = 0
print(a)
# Out:
# 0

# %%
a = True
type(a)
# Out:
# bool

# %%
if a:
    print('True!')
# Out:
# True!

# %%
if 1:{
    print('True')
}
else:{
    print('False')
}
# Out:
# True

# %%
b =None
type(b)
# Out:
# NoneType

# %%
if b:
    print('True')

# %%
a = [1, 2, 3]
type(a)
# Out:
# list

# %%
a[0]
# Out:
# 1

# %%
a[0] + a[2]
# Out:
# 4

# %%
a[0:1]
# Out:
# [1]

# %%
b = [a, 4]
b
# Out:
# [[1, 2, 3], 4]

# %%
b[0][-1]
# Out:
# 3
